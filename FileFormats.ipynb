# %%
##Json Data
data=sqlCtx.read.json("file:///E:/Eclipse_Android_workspaces/ApacheSpark/data/fileformats/jsonInput.json")
sqlCtx.registerDataFrameAsTable(data,'jsonTable')
out=sqlCtx.sql("select * from jsonTable where string='string1'")
out.collect()
# Out:
# [Row(array=[1, 2, 3], dict=Row(extra_key=None, key='value1'), int=1, string='string1')]

# %%
##csv data
csv=sqlCtx.read.csv("file:///E:/Eclipse_Android_workspaces/ApacheSpark/data/fileformats/csvInput.csv")
outCsv=csv.filter(csv['_c0']=='ZABU')
outCsv.collect()
# Out:
# [Row(_c0='ZABU', _c1='N 17', _c2=None),
#  Row(_c0='ZABU', _c1='M/TIO@ 6', _c2=None),
#  Row(_c0='ZABU', _c1='UX 62', _c2=None),
#  Row(_c0='ZABU', _c1='UX 63', _c2=None),
#  Row(_c0='ZABU', _c1='X:HY 3', _c2=None),
#  Row(_c0='ZABU', _c1='M/FAN 2', _c2=None),
#  Row(_c0='ZABU', _c1='M/FAN 4', _c2=None),
#  Row(_c0='ZABU', _c1='UX@ 12', _c2=None),
#  Row(_c0='ZABU', _c1='UX 274', _c2=None),
#  Row(_c0='ZABU', _c1='UX 10', _c2=None),
#  Row(_c0='ZABU', _c1='X:HY 5', _c2=None),
#  Row(_c0='ZABU', _c1='TM/U 1', _c2=None),
#  Row(_c0='ZABU', _c1='A 256', _c2=None),
#  Row(_c0='ZABU', _c1='H2 111', _c2=None),
#  Row(_c0='ZABU', _c1='UX 115', _c2=None),
#  Row(_c0='ZABU', _c1='UX 116', _c2=None),
#  Row(_c0='ZABU', _c1='UX 275', _c2=None),
#  Row(_c0='ZABU', _c1='M/TIO 17', _c2=None),
#  Row(_c0='ZABU', _c1='KZ3 11', _c2=None),
#  Row(_c0='ZABU', _c1='KZ3 12', _c2=None),
#  Row(_c0='ZABU', _c1='KZ3 28', _c2=None),
#  Row(_c0='ZABU', _c1='KZ3 29', _c2=None),
# ...
